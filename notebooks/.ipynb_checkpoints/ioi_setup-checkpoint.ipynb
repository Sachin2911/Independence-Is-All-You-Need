# %% [markdown]
# ## Imports and Configs

# %%
import sys
from pathlib import Path
#Setting the repo root so all of the folders and sub-folders are easily accessible
REPO_ROOT = Path.cwd().parent
sys.path.append(str(REPO_ROOT))


from experiments.helpers.ioi_dataset import IOIDataset #Main dataset class
import experiments.helpers.ioi_dataset as ioi_module #So we can access the nice variable lists easily

#Standard imports
import torch
import random
import numpy as np
from pathlib import Path
from huggingface_hub import login
from transformer_lens import HookedTransformer

N_PROMPTS = 5000

# %%
device = "cuda" #The SAE and model can't run on the CPU
#Setting up the dataset dir
DATA_DIR = REPO_ROOT / "data"
DATA_DIR.mkdir(exist_ok=True)

#For reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
set_seed(42)

# %% [markdown]
# ## Logging into HF

# %%
#Logging into hf so we can access the model weights
login()

# %% [markdown]
# ## Loading in the model weights

# %%
#Loading in the Gemma model, note we are gonna use the base model coz the SAEs weren't trained on the instruct
#and we really only need the next token for IOI
model = HookedTransformer.from_pretrained_no_processing(
    "gemma-2-2b",
    device=device,
    dtype=torch.bfloat16,   # Gemma was trained in bf16 so no need for FP32
)
model.eval() #We do this so that the dropout layers don't have any effect
tokenizer = model.tokenizer #We will need this so we can change the padding token to right instead of left which IOI GPT 2 was designed for
# Out:
# Loading weights:   0%|          | 0/288 [00:00<?, ?it/s]
# Loaded pretrained model gemma-2-2b into HookedTransformer

# %%
#What the tokenizer object has:
print(f"The Model is: {model.cfg.model_name}")
#The res stream that flows through, the layers are one attention(multi-head), one mlp
print(f"Dim of the res stream: {model.cfg.d_model}, n_layers: {model.cfg.n_layers}") 
print(f"BOS token: {tokenizer.bos_token!r} (id={tokenizer.bos_token_id})") #Basically SOS token
print(f"PAD token: {tokenizer.pad_token!r} (id={tokenizer.pad_token_id})")
tokenizer.padding_side = "right" #We'll set this to right so then the first pad token we see will basically function as the end of output for us
# Out:
# The Model is: gemma-2-2b
# Dim of the res stream: 2304, n_layers: 26
# BOS token: '<bos>' (id=2)
# PAD token: '<pad>' (id=0)

# %% [markdown]
# ## Processing the names, places and objects

# %%
original_names = ioi_module.NAMES.copy()
original_places = ioi_module.PLACES.copy()
original_objs = ioi_module.OBJECTS.copy()

# %%
print(f"Here are some of the names: {original_names[:5]}, here are how many they are: {len(original_names)}")
print(f"Here are some of the places: {original_places[:5]}, here are how many they are: {len(original_places)}")
print(f"Here are some of the objects: {original_objs[:5]}, here are how many they are: {len(original_objs)}")
# Out:
# Here are some of the names: ['Michael', 'Christopher', 'Jessica', 'Matthew', 'Ashley'], here are how many they are: 99
# Here are some of the places: ['store', 'garden', 'restaurant', 'school', 'hospital'], here are how many they are: 8
# Here are some of the objects: ['ring', 'kiss', 'bone', 'basketball', 'computer'], here are how many they are: 8

# %%
#Next we tokenize all of these words, I've decided to do this so we can just check if any tokenize to more...
#...than one token. It's important we filter these out, if there are, as we only want to work with the next token prediction
def assert_single_token(words, label):
    multi = [w for w in words if len(tokenizer.encode(" " + w, add_special_tokens=False)) != 1]
    msg = f"{label}: {len(words) - len(multi)}/{len(words)} single-token. Multi: {multi}"
    if multi:
        raise AssertionError(msg)
    print(msg + (" ok " if not multi else " not ok "))
 
assert_single_token(ioi_module.NAMES,   "NAMES")
assert_single_token(ioi_module.PLACES,  "PLACES")
assert_single_token(ioi_module.OBJECTS, "OBJECTS")
# Out:
# NAMES: 99/99 single-token. Multi: [] ok
# PLACES: 8/8 single-token. Multi: [] ok
# OBJECTS: 8/8 single-token. Multi: [] ok

# %% [markdown]
# ## Generating the dataset

# %%
print(f"Generating clean IOI dataset (N={N_PROMPTS})")
 
clean_dataset = IOIDataset(
    prompt_type="mixed",# half ABBA, half BABA where A is the obj, B the subject, nice to have some diversity
    N=N_PROMPTS,
    tokenizer=tokenizer,
    prepend_bos=False,# Gemma will handle the BOS
    symmetric=False,
)
# Out:
# Generating clean IOI dataset (N=5000)

# %%
print(f"Generated {len(clean_dataset)} prompts")
print(f"Example sentence: {clean_dataset.sentences[0]}")
print(f"  IO/S: {clean_dataset.ioi_prompts[0]['IO']} / {clean_dataset.ioi_prompts[0]['S']}")
print(f"The shape of the dataset: {tuple(clean_dataset.toks.shape)}")
# Out:
# Generated 5000 prompts
# Example sentence: Then, Matthew and Robert had a lot of fun at the school. Robert gave a ring to Matthew
#   IO/S: Matthew / Robert
# The shape of the dataset: (5000, 22)

# %%
bos_id = tokenizer.bos_token_id
first, second = clean_dataset.toks[0, 0].item(), clean_dataset.toks[0, 1].item()

print("\nFirst prompt token-by-token (first 8 tokens):")
for i, tok_id in enumerate(clean_dataset.toks[0].tolist()):
    print(f"  [{i}] id={tok_id}  {tokenizer.decode([tok_id])}")
 
print(f"IO token: id={clean_dataset.io_tokenIDs[0]}, "
      f"decoded={tokenizer.decode([clean_dataset.io_tokenIDs[0]])}")
print(f"S  token: id={clean_dataset.s_tokenIDs[0]}, "
      f"decoded={tokenizer.decode([clean_dataset.s_tokenIDs[0]])}")
print(f"End position: {clean_dataset.word_idx['end'][0].item()}")
# Out:
# First prompt token-by-token (first 8 tokens):
#   [0] id=2  <bos>
#   [1] id=7409  Then
#   [2] id=235269  ,
#   [3] id=23739   Matthew
#   [4] id=578   and
#   [5] id=7866   Robert
#   [6] id=1093   had
#   [7] id=476   a
#   [8] id=2940   lot
#   [9] id=576   of
#   [10] id=2245   fun
#   [11] id=696   at
#   [12] id=573   the
#   [13] id=2493   school
#   [14] id=235265  .
#   [15] id=7866   Robert
#   [16] id=5645   gave
#   [17] id=476   a
#   [18] id=7408   ring
#   [19] id=577   to
#   [20] id=23739   Matthew
#   [21] id=0  <pad>
# IO token: id=23739, decoded= Matthew
# S  token: id=7866, decoded= Robert
# End position: 19

# %%
#Now we can generate the corrupted dataset where the Subject and the indirect obj are flipped
print("\nGenerating corrupted dataset...")
corrupted_dataset = clean_dataset.gen_flipped_prompts(("S", "IO"))

print(f"Clean[0]:     {clean_dataset.sentences[0]}")
print(f"Corrupted[0]: {corrupted_dataset.sentences[0]}")
# Out:
# Generating corrupted dataset...
# Clean[0]:     Then, Matthew and Robert had a lot of fun at the school. Robert gave a ring to Matthew
# Corrupted[0]: Then, Robert and Matthew had a lot of fun at the school. Matthew gave a ring to Robert

# %%
print("\n" + "=" * 60)
print("SANITY CHECK — running clean prompts through Gemma")
print("=" * 60)
 
clean_toks    = clean_dataset.toks.to(device)
io_token_ids  = torch.tensor(clean_dataset.io_tokenIDs).to(device)
s_token_ids   = torch.tensor(clean_dataset.s_tokenIDs).to(device)
end_positions = clean_dataset.word_idx["end"].to(device)
 
logit_diffs, correct, total, batch_size = [], 0, 0, 16
 
with torch.no_grad():
    for i in range(0, N_PROMPTS, batch_size):
        batch_toks   = clean_toks[i:i + batch_size]
        batch_logits = model(batch_toks)                          # [B, seq, vocab]
 
        batch_idx    = torch.arange(batch_toks.shape[0], device=device)
        batch_ends   = end_positions[i:i + batch_size]
        final_logits = batch_logits[batch_idx, batch_ends]        # [B, vocab]
 
        io_l = final_logits.gather(1, io_token_ids[i:i + batch_size].unsqueeze(1)).squeeze(1)
        s_l  = final_logits.gather(1, s_token_ids [i:i + batch_size].unsqueeze(1)).squeeze(1)
 
        diff = (io_l - s_l).float()
        logit_diffs.append(diff.cpu())
        correct += (diff > 0).sum().item()
        total   += diff.shape[0]
 
logit_diffs = torch.cat(logit_diffs)
mean_diff   = logit_diffs.mean().item()
accuracy    = correct / total
 
print(f"\nMean logit difference (IO - S): {mean_diff:+.3f}")
print(f"Accuracy (IO logit > S logit):  {accuracy:.1%}")
print(f"Std of logit diff:               {logit_diffs.std().item():.3f}")
# Out:
# ============================================================
# SANITY CHECK — running clean prompts through Gemma
# ============================================================
#
# Mean logit difference (IO - S): +5.249
# Accuracy (IO logit > S logit):  100.0%
# Std of logit diff:               1.514

# %%
corrupted_dataset.sentences
# Out:
# ['Then, Robert and Matthew had a lot of fun at the school. Matthew gave a ring to Robert',
#  'Then, Vanessa and Nicholas were working at the house. Nicholas decided to give a basketball to Vanessa',
#  'Then, Andrea and Thomas were working at the restaurant. Andrea decided to give a drink to Thomas',
#  'Then, Sarah and Thomas had a long argument, and afterwards Thomas said to Sarah',
#  'After John and Amy went to the office, Amy gave a computer to John',
#  'Then, Jennifer and Christine had a lot of fun at the garden. Jennifer gave a drink to Christine',
#  'After Christina and Paul went to the office, Paul gave a basketball to Christina',
#  'Then, Daniel and Jennifer went to the school. Daniel gave a computer to Jennifer',
#  'After John and Elizabeth went to the hospital, Elizabeth gave a snack to John',
#  'Then, Kimberly and William had a long argument, and afterwards Kimberly said to William',
#  'Then, Steven and Lindsay had a long argument, and afterwards Steven said to Lindsay',
#  'Then, Megan and Christine were working at the station. Christine decided to give a drink to Megan',
#  'When Katie and Kenneth got a necklace at the school, Kenneth decided to give it to Katie',
#  'Then, Amanda and Samuel were thinking about going to the store. Samuel wanted to give a necklace to Amanda',
#  'After Steven and Daniel went to the office, Steven gave a basketball to Daniel',
#  'Then, Erin and Michelle had a long argument, and afterwards Erin said to Michelle',
#  'When Megan and Jason got a drink at the hospital, Jason decided to give it to Megan',
#  'Then, Tiffany and Kimberly were thinking about going to the restaurant. Tiffany wanted to give a snack to Kimberly',
#  'After Joshua and Allison went to the restaurant, Allison gave a bone to Joshua',
#  'Then, Jesse and Mark had a lot of fun at the garden. Jesse gave a drink to Mark',
#  'After Gregory and Jacob went to the hospital, Gregory gave a ring to Jacob',
#  'Then, Courtney and Andrew had a long argument, and afterwards Courtney said to Andrew',
#  'After Emily and Christina went to the station, Christina gave a ring to Emily',
#  'Then, Courtney and Kevin went to the restaurant. Courtney gave a kiss to Kevin',
#  'Then, Kyle and Lisa were thinking about going to the school. Lisa wanted to give a bone to Kyle',
#  'Then, William and Bradley had a long argument, and afterwards Bradley said to William',
#  'Then, Jessica and Andrew were working at the hospital. Jessica decided to give a basketball to Andrew',
#  'Then, Tyler and Adam had a lot of fun at the garden. Adam gave a snack to Tyler',
#  'Then, Bradley and Daniel were thinking about going to the restaurant. Daniel wanted to give a bone to Bradley',
#  'Then, Stephen and Paul had a long argument, and afterwards Stephen said to Paul',
#  'When Dustin and Allison got a computer at the school, Dustin decided to give it to Allison',
#  'After Jose and Lindsey went to the station, Jose gave a snack to Lindsey',
#  'After Eric and Megan went to the office, Megan gave a ring to Eric',
#  'Then, Paul and Elizabeth were thinking about going to the school. Paul wanted to give a ring to Elizabeth',
#  'After Lisa and Shannon went to the school, Shannon gave a kiss to Lisa',
#  'Then, David and Amber had a lot of fun at the school. Amber gave a computer to David',
#  'Then, Sean and Heather had a long argument, and afterwards Sean said to Heather',
#  'When Stephen and Jeremy got a kiss at the garden, Stephen decided to give it to Jeremy',
#  'Then, Emily and Richard had a long argument, and afterwards Emily said to Richard',
#  'Then, Joshua and Christine were thinking about going to the garden. Christine wanted to give a ring to Joshua',
#  'After Christine and Brittany went to the school, Christine gave a basketball to Brittany',
#  'When Sara and Charles got a bone at the house, Sara decided to give it to Charles',
#  'When Megan and Jacob got a kiss at the station, Jacob decided to give it to Megan',
#  'Then, Dustin and Lindsey had a lot of fun at the garden. Lindsey gave a basketball to Dustin',
#  'Then, Sean and Jeremy went to the school. Jeremy gave a drink to Sean',
#  'Then, Amy and Jonathan had a lot of fun at the house. Jonathan gave a computer to Amy',
#  'Then, Rebecca and Timothy had a lot of fun at the station. Rebecca gave a bone to Timothy',
#  'When Christina and Heather got a necklace at the store, Christina decided to give it to Heather',
#  'Then, Katherine and Joshua had a lot of fun at the restaurant. Joshua gave a ring to Katherine',
#  'Then, Brian and James were working at the garden. James decided to give a basketball to Brian',
#  'After Ryan and Tyler went to the store, Ryan gave a kiss to Tyler',
#  'After Kristen and Katherine went to the office, Kristen gave a computer to Katherine',
#  'When Jose and Vanessa got a computer at the school, Jose decided to give it to Vanessa',
#  'After Brandon and Jose went to the hospital, Brandon gave a snack to Jose',
#  'Then, David and Allison had a long argument, and afterwards Allison said to David',
#  'After Heather and Sara went to the hospital, Sara gave a bone to Heather',
#  'Then, Megan and Daniel had a long argument, and afterwards Daniel said to Megan',
#  'Then, Dustin and Shannon were working at the store. Dustin decided to give a computer to Shannon',
#  'Then, Joseph and Jason had a long argument, and afterwards Joseph said to Jason',
#  'Then, Paul and Sarah went to the hospital. Paul gave a basketball to Sarah',
#  'Then, Brittany and Anthony went to the hospital. Brittany gave a snack to Anthony',
#  'When Robert and Joshua got a computer at the house, Joshua decided to give it to Robert',
#  'Then, Amber and Michael had a lot of fun at the restaurant. Michael gave a computer to Amber',
#  'Then, Aaron and Alicia went to the house. Alicia gave a ring to Aaron',
#  'After Katie and David went to the store, David gave a necklace to Katie',
#  'Then, Paul and Justin were thinking about going to the restaurant. Paul wanted to give a ring to Justin',
#  'When Jennifer and Kimberly got a basketball at the school, Kimberly decided to give it to Jennifer',
#  'Then, Joseph and Richard had a long argument, and afterwards Joseph said to Richard',
#  'When William and Stephanie got a bone at the store, William decided to give it to Stephanie',
#  'Then, Amber and Jeremy went to the school. Amber gave a computer to Jeremy',
#  'Then, Joseph and Lindsay went to the store. Lindsay gave a snack to Joseph',
#  'When Nicholas and Rebecca got a basketball at the hospital, Nicholas decided to give it to Rebecca',
#  'When Matthew and Kristen got a necklace at the house, Matthew decided to give it to Kristen',
#  'When Samuel and Daniel got a drink at the office, Daniel decided to give it to Samuel',
#  'Then, Sara and Amber had a long argument, and afterwards Sara said to Amber',
#  'Then, Kevin and Katherine went to the garden. Katherine gave a drink to Kevin',
#  'Then, Laura and Christine had a long argument, and afterwards Christine said to Laura',
#  'Then, Nicole and Melissa were thinking about going to the house. Nicole wanted to give a ring to Melissa',
#  'Then, Jesse and Sara were working at the school. Sara decided to give a necklace to Jesse',
#  'After Daniel and Jose went to the office, Daniel gave a kiss to Jose',
#  'Then, Kyle and Jamie went to the house. Kyle gave a necklace to Jamie',
#  'After Lindsay and Christina went to the restaurant, Lindsay gave a basketball to Christina',
#  'After Jose and Amy went to the restaurant, Jose gave a computer to Amy',
#  'After Paul and Michael went to the hospital, Paul gave a basketball to Michael',
#  'After Katherine and Erica went to the office, Katherine gave a snack to Erica',
#  'Then, Aaron and Alexander were working at the station. Aaron decided to give a bone to Alexander',
#  'Then, James and Timothy had a long argument, and afterwards James said to Timothy',
#  'Then, Adam and Allison were thinking about going to the hospital. Allison wanted to give a basketball to Adam',
#  'Then, Nicholas and Justin had a lot of fun at the store. Nicholas gave a basketball to Justin',
#  'Then, Mary and Samuel were working at the station. Mary decided to give a drink to Samuel',
#  'Then, Scott and Nicole had a long argument, and afterwards Scott said to Nicole',
#  'After Megan and Justin went to the store, Megan gave a kiss to Justin',
#  'Then, Mark and Eric had a lot of fun at the station. Mark gave a ring to Eric',
#  'Then, Ryan and Megan were working at the restaurant. Megan decided to give a snack to Ryan',
#  'Then, Nathan and Angela had a long argument, and afterwards Nathan said to Angela',
#  'Then, Courtney and Jamie were thinking about going to the station. Courtney wanted to give a bone to Jamie',
#  'Then, Stephen and Charles went to the school. Stephen gave a computer to Charles',
#  'Then, Samantha and Sean had a lot of fun at the school. Samantha gave a computer to Sean',
#  'Then, David and Vanessa were working at the school. David decided to give a computer to Vanessa',
#  'Then, Dustin and Laura had a long argument, and afterwards Laura said to Dustin',
#  'When Crystal and Katie got a kiss at the school, Crystal decided to give it to Katie',
#  'After Jeremy and Amber went to the station, Jeremy gave a drink to Amber',
#  'Then, Benjamin and Anthony had a lot of fun at the store. Anthony gave a drink to Benjamin',
#  'Then, Michael and Richard were working at the house. Michael decided to give a drink to Richard',
#  'Then, Alicia and Cody were working at the school. Cody decided to give a snack to Alicia',
#  'When Steven and Emily got a drink at the store, Steven decided to give it to Emily',
#  'Then, Alexander and Jose had a long argument, and afterwards Jose said to Alexander',
#  'Then, Sara and Travis went to the house. Travis gave a ring to Sara',
#  'After Mark and Bryan went to the station, Bryan gave a bone to Mark',
#  'Then, Amy and Kevin had a lot of fun at the school. Kevin gave a snack to Amy',
#  'Then, Bradley and Brittany had a long argument, and afterwards Brittany said to Bradley',
#  'When Stephen and James got a necklace at the store, James decided to give it to Stephen',
#  'When Jennifer and Allison got a basketball at the school, Jennifer decided to give it to Allison',
#  'Then, Travis and Jessica were thinking about going to the school. Jessica wanted to give a bone to Travis',
#  'Then, Jose and Andrew were working at the school. Jose decided to give a snack to Andrew',
#  'Then, Melissa and Samuel went to the restaurant. Melissa gave a kiss to Samuel',
#  'Then, William and Rachel had a lot of fun at the store. William gave a computer to Rachel',
#  'Then, Alexander and Amy were thinking about going to the school. Alexander wanted to give a kiss to Amy',
#  'Then, Katie and Lisa were thinking about going to the garden. Katie wanted to give a computer to Lisa',
#  'Then, Gregory and Jesse were thinking about going to the store. Jesse wanted to give a necklace to Gregory',
#  'Then, Kristen and Mark were working at the garden. Mark decided to give a necklace to Kristen',
#  'Then, Sean and Benjamin had a lot of fun at the house. Benjamin gave a necklace to Sean',
#  'Then, Rebecca and Shannon had a long argument, and afterwards Rebecca said to Shannon',
#  'Then, Samantha and Lindsey went to the station. Samantha gave a snack to Lindsey',
#  'After Christine and Andrea went to the office, Christine gave a basketball to Andrea',
#  'Then, Thomas and Robert were thinking about going to the school. Robert wanted to give a snack to Thomas',
#  'Then, Mary and Jose were thinking about going to the office. Mary wanted to give a ring to Jose',
#  'Then, Lauren and Brian were working at the school. Lauren decided to give a necklace to Brian',
#  'Then, Kevin and Brittany had a lot of fun at the hospital. Kevin gave a ring to Brittany',
#  'Then, James and Nicole were working at the house. Nicole decided to give a snack to James',
#  'Then, Adam and Bradley were working at the station. Bradley decided to give a snack to Adam',
#  'Then, Jessica and Robert were working at the school. Jessica decided to give a drink to Robert',
#  'Then, Megan and Rachel went to the office. Megan gave a snack to Rachel',
#  'Then, Danielle and Nathan were working at the office. Nathan decided to give a necklace to Danielle',
#  'Then, Rebecca and Steven went to the hospital. Rebecca gave a basketball to Steven',
#  'After Nicole and Courtney went to the garden, Courtney gave a bone to Nicole',
#  'When Heather and Alicia got a computer at the hospital, Heather decided to give it to Alicia',
#  'After Christina and Nicole went to the office, Nicole gave a bone to Christina',
#  'When Shannon and Christopher got a computer at the restaurant, Christopher decided to give it to Shannon',
#  'Then, Paul and Joshua had a lot of fun at the restaurant. Joshua gave a snack to Paul',
#  'After Scott and Christopher went to the station, Christopher gave a snack to Scott',
#  'Then, Brittany and Brian were working at the hospital. Brittany decided to give a snack to Brian',
#  'After Tiffany and Daniel went to the garden, Daniel gave a ring to Tiffany',
#  'Then, Tyler and Sarah went to the garden. Sarah gave a basketball to Tyler',
#  'After Bradley and Angela went to the school, Angela gave a drink to Bradley',
#  'Then, Aaron and Kyle were working at the house. Aaron decided to give a computer to Kyle',
#  'Then, Travis and Amanda were thinking about going to the garden. Travis wanted to give a basketball to Amanda',
#  'Then, Heather and Kevin had a long argument, and afterwards Heather said to Kevin',
#  'When Stephanie and Paul got a ring at the restaurant, Stephanie decided to give it to Paul',
#  'After Charles and Katie went to the station, Charles gave a computer to Katie',
#  'Then, Timothy and Elizabeth had a lot of fun at the hospital. Elizabeth gave a snack to Timothy',
#  'After Elizabeth and Jesse went to the school, Jesse gave a drink to Elizabeth',
#  'After Eric and Dustin went to the restaurant, Dustin gave a computer to Eric',
#  'Then, David and Justin were thinking about going to the restaurant. Justin wanted to give a computer to David',
#  'Then, Cody and Tyler were thinking about going to the station. Cody wanted to give a kiss to Tyler',
#  'Then, Katie and Kyle were working at the house. Katie decided to give a computer to Kyle',
#  'Then, Erin and Dustin were working at the garden. Dustin decided to give a ring to Erin',
#  'After Alicia and Lauren went to the hospital, Alicia gave a ring to Lauren',
#  'After Alexander and Elizabeth went to the store, Elizabeth gave a computer to Alexander',
#  'Then, Jennifer and Bradley were thinking about going to the restaurant. Jennifer wanted to give a snack to Bradley',
#  'Then, Aaron and Lindsey were working at the restaurant. Lindsey decided to give a drink to Aaron',
#  'Then, Sean and Robert had a long argument, and afterwards Sean said to Robert',
#  'Then, Jose and Lauren had a long argument, and afterwards Lauren said to Jose',
#  'After Katie and Erin went to the house, Katie gave a ring to Erin',
#  'Then, Robert and Laura were working at the office. Robert decided to give a kiss to Laura',
#  'Then, Tiffany and Kelly had a lot of fun at the station. Tiffany gave a drink to Kelly',
#  'Then, Samantha and Nicole had a lot of fun at the station. Nicole gave a snack to Samantha',
#  'Then, Joshua and Anthony had a lot of fun at the restaurant. Joshua gave a computer to Anthony',
#  'Then, Lindsay and Sean were working at the store. Lindsay decided to give a basketball to Sean',
#  'Then, William and Rachel went to the store. William gave a drink to Rachel',
#  'After Andrew and Eric went to the garden, Eric gave a bone to Andrew',
#  'Then, Vanessa and Christina were working at the hospital. Vanessa decided to give a drink to Christina',
#  'Then, Stephen and Patrick were thinking about going to the station. Patrick wanted to give a bone to Stephen',
#  'After Nicole and Gregory went to the restaurant, Nicole gave a kiss to Gregory',
#  'When Benjamin and Samuel got a ring at the hospital, Samuel decided to give it to Benjamin',
#  'When Kyle and Courtney got a bone at the station, Courtney decided to give it to Kyle',
#  'Then, Sara and Patrick were working at the office. Sara decided to give a drink to Patrick',
#  'Then, Lauren and Nicole were working at the school. Lauren decided to give a drink to Nicole',
#  'When Jeremy and Jennifer got a drink at the station, Jeremy decided to give it to Jennifer',
#  'After Kristen and Lindsey went to the station, Kristen gave a ring to Lindsey',
#  'Then, Andrea and Jamie went to the garden. Jamie gave a snack to Andrea',
#  'After Rebecca and Nathan went to the restaurant, Nathan gave a drink to Rebecca',
#  'Then, Sarah and Lindsey were thinking about going to the station. Lindsey wanted to give a computer to Sarah',
#  'Then, Katie and Travis had a long argument, and afterwards Travis said to Katie',
#  'Then, Sara and Alexander were thinking about going to the office. Alexander wanted to give a snack to Sara',
#  'Then, Ashley and Dustin were thinking about going to the garden. Dustin wanted to give a basketball to Ashley',
#  'Then, Jesse and Timothy had a long argument, and afterwards Jesse said to Timothy',
#  'After Kenneth and Bradley went to the garden, Bradley gave a snack to Kenneth',
#  'Then, Kyle and Katie went to the store. Katie gave a necklace to Kyle',
#  'Then, Amanda and Christina had a lot of fun at the office. Amanda gave a drink to Christina',
#  'Then, Nathan and Megan went to the restaurant. Megan gave a bone to Nathan',
#  'Then, Mary and James went to the school. James gave a snack to Mary',
#  'Then, Justin and Elizabeth were thinking about going to the hospital. Justin wanted to give a snack to Elizabeth',
#  'When Christopher and Jose got a bone at the hospital, Jose decided to give it to Christopher',
#  'After Danielle and Aaron went to the hospital, Aaron gave a drink to Danielle',
#  'Then, Melissa and Rebecca went to the school. Melissa gave a drink to Rebecca',
#  'Then, Joseph and Patrick were thinking about going to the house. Patrick wanted to give a necklace to Joseph',
#  'Then, Jessica and Kristen were thinking about going to the hospital. Jessica wanted to give a ring to Kristen',
#  'Then, Jesse and Cody were thinking about going to the station. Jesse wanted to give a computer to Cody',
#  'Then, Elizabeth and Erica had a lot of fun at the school. Elizabeth gave a basketball to Erica',
#  'Then, Melissa and Alexander were thinking about going to the restaurant. Melissa wanted to give a kiss to Alexander',
#  'Then, Bryan and Jennifer had a long argument, and afterwards Bryan said to Jennifer',
#  'Then, Kimberly and Christine were thinking about going to the garden. Kimberly wanted to give a computer to Christine',
#  'Then, Benjamin and Cody had a long argument, and afterwards Cody said to Benjamin',
#  'Then, Dustin and Kimberly had a lot of fun at the hospital. Dustin gave a bone to Kimberly',
#  'When Christina and Patrick got a kiss at the office, Patrick decided to give it to Christina',
#  'Then, David and Justin were working at the school. David decided to give a drink to Justin',
#  'Then, Kimberly and Angela were thinking about going to the house. Angela wanted to give a ring to Kimberly',
#  'When Ryan and Sara got a computer at the office, Sara decided to give it to Ryan',
#  'Then, Amy and Kenneth were thinking about going to the garden. Amy wanted to give a basketball to Kenneth',
#  'Then, Matthew and Travis were working at the office. Matthew decided to give a basketball to Travis',
#  'Then, Daniel and Kenneth had a long argument, and afterwards Daniel said to Kenneth',
#  'After Jennifer and Jason went to the hospital, Jason gave a snack to Jennifer',
#  'After Adam and John went to the restaurant, John gave a drink to Adam',
#  'Then, Jeffrey and Jose were working at the house. Jeffrey decided to give a bone to Jose',
#  'After Lindsey and John went to the house, Lindsey gave a computer to John',
#  'Then, Jeffrey and Katie had a lot of fun at the station. Katie gave a snack to Jeffrey',
#  'When Kimberly and John got a necklace at the office, Kimberly decided to give it to John',
#  'Then, Thomas and Michelle had a lot of fun at the garden. Michelle gave a snack to Thomas',
#  'After Heather and Kristen went to the store, Kristen gave a ring to Heather',
#  'Then, Amber and Megan had a lot of fun at the school. Amber gave a kiss to Megan',
#  'Then, Paul and Bradley were thinking about going to the school. Bradley wanted to give a basketball to Paul',
#  'Then, Gregory and Justin had a long argument, and afterwards Justin said to Gregory',
#  'Then, Melissa and Dustin went to the garden. Dustin gave a ring to Melissa',
#  'Then, Richard and Christopher went to the office. Christopher gave a ring to Richard',
#  'Then, Joshua and Kevin went to the house. Kevin gave a kiss to Joshua',
#  'Then, Daniel and Stephen went to the office. Daniel gave a kiss to Stephen',
#  'Then, Jamie and Eric were working at the store. Jamie decided to give a computer to Eric',
#  'Then, Bryan and Matthew were working at the station. Bryan decided to give a drink to Matthew',
#  'After Jesse and Joseph went to the station, Jesse gave a kiss to Joseph',
#  'After Erica and Lauren went to the garden, Lauren gave a bone to Erica',
#  'When Kenneth and Travis got a drink at the office, Travis decided to give it to Kenneth',
#  'Then, Nathan and Christina were thinking about going to the house. Nathan wanted to give a kiss to Christina',
#  'Then, Lindsay and Andrew had a lot of fun at the school. Lindsay gave a drink to Andrew',
#  'Then, Elizabeth and Jeremy were working at the station. Elizabeth decided to give a drink to Jeremy',
#  'After Christine and John went to the house, Christine gave a necklace to John',
#  'Then, Melissa and Jeffrey had a long argument, and afterwards Melissa said to Jeffrey',
#  'After Robert and James went to the garden, James gave a necklace to Robert',
#  'Then, Brandon and Angela had a lot of fun at the office. Brandon gave a kiss to Angela',
#  'After Richard and Jose went to the house, Richard gave a ring to Jose',
#  'When Rachel and Gregory got a basketball at the garden, Gregory decided to give it to Rachel',
#  'Then, Patrick and Kristen went to the garden. Kristen gave a necklace to Patrick',
#  'Then, Jeffrey and Angela were thinking about going to the hospital. Angela wanted to give a basketball to Jeffrey',
#  'Then, Mark and Angela had a lot of fun at the store. Mark gave a computer to Angela',
#  'Then, Steven and Brian had a lot of fun at the hospital. Brian gave a necklace to Steven',
#  'Then, Brian and Michael had a long argument, and afterwards Michael said to Brian',
#  'Then, Kenneth and Alicia went to the garden. Alicia gave a basketball to Kenneth',
#  'After Benjamin and Rebecca went to the restaurant, Benjamin gave a necklace to Rebecca',
#  'When Lauren and Courtney got a ring at the garden, Courtney decided to give it to Lauren',
#  'Then, Allison and William went to the store. William gave a kiss to Allison',
#  'When Kristen and Aaron got a snack at the station, Aaron decided to give it to Kristen',
#  'After Steven and Heather went to the garden, Steven gave a necklace to Heather',
#  'After Andrew and Timothy went to the station, Andrew gave a computer to Timothy',
#  'Then, Michelle and Eric had a lot of fun at the store. Eric gave a ring to Michelle',
#  'When Kyle and Heather got a computer at the restaurant, Kyle decided to give it to Heather',
#  'When Ryan and Lauren got a drink at the station, Lauren decided to give it to Ryan',
#  'Then, Amy and Brandon went to the school. Brandon gave a necklace to Amy',
#  'After Alicia and Michelle went to the house, Michelle gave a ring to Alicia',
#  'Then, David and Laura were working at the house. David decided to give a drink to Laura',
#  'Then, Kenneth and Benjamin went to the garden. Kenneth gave a drink to Benjamin',
#  'Then, Jonathan and Lauren had a lot of fun at the station. Lauren gave a necklace to Jonathan',
#  'After Joseph and Emily went to the house, Emily gave a drink to Joseph',
#  'Then, Michelle and James were working at the office. James decided to give a basketball to Michelle',
#  'Then, David and Jonathan had a long argument, and afterwards Jonathan said to David',
#  'Then, Bryan and Justin had a lot of fun at the garden. Bryan gave a bone to Justin',
#  'When Stephanie and Nicholas got a kiss at the restaurant, Nicholas decided to give it to Stephanie',
#  'Then, Lisa and Samuel went to the station. Samuel gave a snack to Lisa',
#  'Then, Tyler and Bryan had a long argument, and afterwards Tyler said to Bryan',
#  'Then, Daniel and Aaron went to the station. Aaron gave a computer to Daniel',
#  'Then, Thomas and Andrea had a lot of fun at the office. Thomas gave a kiss to Andrea',
#  'When Charles and Jacob got a necklace at the store, Jacob decided to give it to Charles',
#  'Then, David and Timothy were thinking about going to the garden. Timothy wanted to give a drink to David',
#  'Then, Katherine and Paul were working at the store. Katherine decided to give a snack to Paul',
#  'Then, Scott and Lindsey had a lot of fun at the office. Scott gave a snack to Lindsey',
#  'Then, Amanda and Sarah were working at the garden. Sarah decided to give a necklace to Amanda',
#  'Then, James and Jamie went to the restaurant. James gave a ring to Jamie',
#  'When Nathan and Samantha got a necklace at the restaurant, Nathan decided to give it to Samantha',
#  'Then, Crystal and Timothy had a long argument, and afterwards Timothy said to Crystal',
#  'Then, Lisa and Bryan had a lot of fun at the garden. Lisa gave a necklace to Bryan',
#  'After Alexander and Angela went to the hospital, Angela gave a computer to Alexander',
#  'Then, Kristen and Erica went to the office. Kristen gave a kiss to Erica',
#  'Then, Kristen and Justin were thinking about going to the hospital. Kristen wanted to give a drink to Justin',
#  'Then, Shannon and Gregory went to the hospital. Gregory gave a drink to Shannon',
#  'Then, Amber and Brandon had a long argument, and afterwards Amber said to Brandon',
#  'Then, Brian and Rachel were working at the office. Rachel decided to give a snack to Brian',
#  'When Eric and Jason got a computer at the garden, Eric decided to give it to Jason',
#  'Then, Jamie and John were thinking about going to the store. John wanted to give a necklace to Jamie',
#  'Then, Travis and Brandon had a lot of fun at the house. Travis gave a bone to Brandon',
#  'Then, Katie and Brian went to the restaurant. Brian gave a snack to Katie',
#  'Then, Kimberly and Jeremy had a lot of fun at the school. Jeremy gave a snack to Kimberly',
#  'Then, Timothy and Allison were thinking about going to the station. Timothy wanted to give a basketball to Allison',
#  'Then, Rachel and Adam were working at the school. Adam decided to give a necklace to Rachel',
#  'Then, Scott and Aaron had a long argument, and afterwards Scott said to Aaron',
#  'Then, Benjamin and Nathan were working at the school. Nathan decided to give a bone to Benjamin',
#  'Then, Joshua and Melissa were thinking about going to the station. Melissa wanted to give a necklace to Joshua',
#  'Then, Vanessa and Joseph were working at the garden. Joseph decided to give a computer to Vanessa',
#  'After William and Bradley went to the station, Bradley gave a bone to William',
#  'Then, Robert and Emily were thinking about going to the station. Emily wanted to give a necklace to Robert',
#  'Then, Joshua and Benjamin had a lot of fun at the office. Benjamin gave a basketball to Joshua',
#  'After James and Jeffrey went to the store, James gave a necklace to Jeffrey',
#  'After Lindsey and Vanessa went to the restaurant, Vanessa gave a bone to Lindsey',
#  'Then, Stephen and Timothy had a lot of fun at the restaurant. Timothy gave a snack to Stephen',
#  'Then, Mary and Michael were working at the store. Mary decided to give a computer to Michael',
#  'When Sarah and Paul got a kiss at the house, Sarah decided to give it to Paul',
#  'Then, Timothy and Adam had a lot of fun at the garden. Timothy gave a ring to Adam',
#  'When Benjamin and Kenneth got a kiss at the station, Benjamin decided to give it to Kenneth',
#  'After Gregory and Erin went to the store, Erin gave a basketball to Gregory',
#  'Then, Justin and Christina went to the store. Justin gave a necklace to Christina',
#  'When Scott and Benjamin got a necklace at the garden, Scott decided to give it to Benjamin',
#  'After Dustin and Nathan went to the store, Nathan gave a drink to Dustin',
#  'Then, Jennifer and Stephen were thinking about going to the house. Stephen wanted to give a necklace to Jennifer',
#  'When Jessica and Cody got a necklace at the garden, Cody decided to give it to Jessica',
#  'When Christine and Kristen got a necklace at the garden, Christine decided to give it to Kristen',
#  'Then, Richard and Jennifer went to the office. Jennifer gave a bone to Richard',
#  'Then, Jacob and Jesse were thinking about going to the station. Jesse wanted to give a bone to Jacob',
#  'Then, Jason and Daniel had a lot of fun at the station. Jason gave a ring to Daniel',
#  'When Laura and Jennifer got a snack at the house, Jennifer decided to give it to Laura',
#  'When Allison and Ashley got a computer at the school, Ashley decided to give it to Allison',
#  'Then, Lindsey and Joshua had a long argument, and afterwards Joshua said to Lindsey',
#  'Then, Jeffrey and Emily had a lot of fun at the station. Jeffrey gave a drink to Emily',
#  'Then, Erin and Brian had a long argument, and afterwards Brian said to Erin',
#  'Then, Samantha and Steven had a lot of fun at the house. Samantha gave a kiss to Steven',
#  'After Erica and Brian went to the hospital, Erica gave a necklace to Brian',
#  'After Lauren and James went to the hospital, James gave a computer to Lauren',
#  'Then, Erica and Vanessa were working at the restaurant. Erica decided to give a snack to Vanessa',
#  'Then, Jennifer and Charles had a long argument, and afterwards Charles said to Jennifer',
#  'When Amanda and Kenneth got a necklace at the house, Kenneth decided to give it to Amanda',
#  'Then, Alexander and Cody were working at the store. Cody decided to give a bone to Alexander',
#  'Then, Alexander and Erica were thinking about going to the store. Erica wanted to give a bone to Alexander',
#  'After Bryan and Adam went to the office, Adam gave a drink to Bryan',
#  'Then, Ashley and Erica were thinking about going to the station. Ashley wanted to give a necklace to Erica',
#  'Then, Bradley and Aaron had a long argument, and afterwards Aaron said to Bradley',
#  'After Laura and Lindsey went to the school, Laura gave a kiss to Lindsey',
#  'Then, Brian and Alicia had a lot of fun at the house. Alicia gave a kiss to Brian',
#  'When Shannon and Kevin got a computer at the school, Kevin decided to give it to Shannon',
#  'Then, Sean and Nicholas went to the restaurant. Sean gave a kiss to Nicholas',
#  'Then, Stephanie and Vanessa were working at the garden. Stephanie decided to give a necklace to Vanessa',
#  'Then, Danielle and Shannon had a long argument, and afterwards Danielle said to Shannon',
#  'Then, Vanessa and William were thinking about going to the restaurant. William wanted to give a necklace to Vanessa',
#  'Then, Ryan and Eric were working at the restaurant. Eric decided to give a basketball to Ryan',
#  'Then, Erin and Matthew had a lot of fun at the office. Erin gave a snack to Matthew',
#  'Then, Paul and Brandon had a lot of fun at the garden. Paul gave a kiss to Brandon',
#  'When Vanessa and Michelle got a drink at the station, Michelle decided to give it to Vanessa',
#  'Then, Jeremy and Scott had a lot of fun at the restaurant. Jeremy gave a necklace to Scott',
#  'Then, David and Charles had a long argument, and afterwards David said to Charles',
#  'Then, Kenneth and Paul were thinking about going to the restaurant. Paul wanted to give a bone to Kenneth',
#  'After Jamie and Amanda went to the restaurant, Jamie gave a computer to Amanda',
#  'Then, Lauren and William went to the school. William gave a necklace to Lauren',
#  'Then, James and Timothy were working at the school. Timothy decided to give a computer to James',
#  'Then, Kyle and Lisa went to the garden. Lisa gave a bone to Kyle',
#  'Then, Katherine and Sarah were thinking about going to the office. Katherine wanted to give a ring to Sarah',
#  'Then, James and Matthew were thinking about going to the hospital. Matthew wanted to give a basketball to James',
#  'Then, Scott and Benjamin had a lot of fun at the store. Scott gave a snack to Benjamin',
#  'Then, Dustin and Christina had a long argument, and afterwards Dustin said to Christina',
#  'When Jesse and Tiffany got a kiss at the station, Jesse decided to give it to Tiffany',
#  'Then, Amanda and William went to the house. Amanda gave a snack to William',
#  'Then, Anthony and Brittany were working at the restaurant. Anthony decided to give a necklace to Brittany',
#  'Then, Laura and Vanessa were thinking about going to the office. Vanessa wanted to give a drink to Laura',
#  'Then, Jeffrey and Bradley went to the garden. Bradley gave a necklace to Jeffrey',
#  'When Jacob and Ryan got a basketball at the station, Jacob decided to give it to Ryan',
#  'Then, Joshua and John went to the house. John gave a drink to Joshua',
#  'When William and Lauren got a basketball at the office, William decided to give it to Lauren',
#  'Then, William and Erin had a lot of fun at the station. William gave a snack to Erin',
#  'When Jessica and Erin got a snack at the house, Erin decided to give it to Jessica',
#  'When Heather and Katherine got a ring at the store, Heather decided to give it to Katherine',
#  'When Gregory and Erin got a computer at the station, Erin decided to give it to Gregory',
#  'Then, Joseph and Christopher were working at the restaurant. Christopher decided to give a computer to Joseph',
#  'Then, Kimberly and Bradley went to the office. Kimberly gave a ring to Bradley',
#  'After Joshua and Tyler went to the school, Joshua gave a necklace to Tyler',
#  'Then, David and Timothy were working at the station. Timothy decided to give a computer to David',
#  'Then, Jesse and Travis were thinking about going to the garden. Travis wanted to give a bone to Jesse',
#  'After Jeffrey and Michelle went to the office, Michelle gave a bone to Jeffrey',
#  'When Erica and Kelly got a ring at the store, Erica decided to give it to Kelly',
#  'Then, Vanessa and Jason had a lot of fun at the station. Jason gave a snack to Vanessa',
#  'Then, Kelly and Erica went to the office. Erica gave a necklace to Kelly',
#  'Then, Mary and Michelle went to the hospital. Michelle gave a necklace to Mary',
#  'Then, Sara and Kelly were working at the hospital. Kelly decided to give a snack to Sara',
#  'Then, Jeffrey and Jessica were thinking about going to the garden. Jessica wanted to give a drink to Jeffrey',
#  'Then, Rachel and Courtney were thinking about going to the store. Rachel wanted to give a snack to Courtney',
#  'When Katherine and Lindsey got a ring at the school, Lindsey decided to give it to Katherine',
#  'Then, Patrick and Jonathan were thinking about going to the house. Patrick wanted to give a bone to Jonathan',
#  'Then, Megan and Jesse were thinking about going to the garden. Jesse wanted to give a basketball to Megan',
#  'Then, Laura and Aaron had a lot of fun at the restaurant. Aaron gave a drink to Laura',
#  'Then, Anthony and Jeremy went to the station. Anthony gave a ring to Jeremy',
#  'Then, Jason and Samantha went to the office. Jason gave a snack to Samantha',
#  'Then, Laura and Amy were working at the station. Amy decided to give a necklace to Laura',
#  'Then, Alexander and Richard were working at the hospital. Richard decided to give a snack to Alexander',
#  'When Megan and Thomas got a basketball at the hospital, Megan decided to give it to Thomas',
#  'When Timothy and Samuel got a snack at the school, Samuel decided to give it to Timothy',
#  'Then, Danielle and Patrick had a long argument, and afterwards Patrick said to Danielle',
#  'After Alexander and Scott went to the house, Scott gave a drink to Alexander',
#  'Then, Samuel and Danielle were thinking about going to the hospital. Danielle wanted to give a ring to Samuel',
#  'When James and Vanessa got a computer at the station, Vanessa decided to give it to James',
#  'Then, Patrick and Heather went to the hospital. Patrick gave a computer to Heather',
#  'Then, Mary and Joseph went to the school. Joseph gave a basketball to Mary',
#  'Then, Nathan and Jose had a lot of fun at the school. Jose gave a ring to Nathan',
#  'After Amber and Jeremy went to the station, Jeremy gave a kiss to Amber',
#  'Then, Samuel and Jason had a long argument, and afterwards Samuel said to Jason',
#  'Then, Stephen and Patrick had a long argument, and afterwards Stephen said to Patrick',
#  'Then, Bryan and Timothy had a long argument, and afterwards Timothy said to Bryan',
#  'Then, Courtney and Alicia were working at the restaurant. Alicia decided to give a drink to Courtney',
#  'Then, Ashley and Stephanie were thinking about going to the station. Stephanie wanted to give a bone to Ashley',
#  'Then, Christina and Ashley went to the hospital. Christina gave a kiss to Ashley',
#  'Then, Rebecca and Timothy had a long argument, and afterwards Timothy said to Rebecca',
#  'Then, Jacob and Jamie were thinking about going to the school. Jamie wanted to give a kiss to Jacob',
#  'Then, Christine and William had a long argument, and afterwards William said to Christine',
#  'Then, Brittany and Alicia had a lot of fun at the school. Alicia gave a bone to Brittany',
#  'Then, Kenneth and Tiffany were thinking about going to the office. Kenneth wanted to give a kiss to Tiffany',
#  'After Jose and John went to the restaurant, Jose gave a snack to John',
#  'Then, Michael and Megan had a long argument, and afterwards Megan said to Michael',
#  'Then, Allison and Steven were working at the hospital. Allison decided to give a ring to Steven',
#  'When Kimberly and Lindsey got a ring at the school, Lindsey decided to give it to Kimberly',
#  'Then, Ryan and Jacob had a long argument, and afterwards Ryan said to Jacob',
#  'Then, Jamie and Shannon had a long argument, and afterwards Jamie said to Shannon',
#  'Then, Christina and Jeffrey had a long argument, and afterwards Christina said to Jeffrey',
#  'Then, Sarah and Patrick went to the office. Patrick gave a drink to Sarah',
#  'Then, Paul and Stephen went to the school. Paul gave a basketball to Stephen',
#  'Then, Allison and Gregory had a long argument, and afterwards Allison said to Gregory',
#  'After Andrew and Tyler went to the school, Tyler gave a bone to Andrew',
#  'Then, Samantha and Lauren went to the garden. Lauren gave a basketball to Samantha',
#  'Then, Katherine and Sean went to the station. Katherine gave a ring to Sean',
#  'Then, Brandon and Kelly were working at the station. Brandon decided to give a ring to Kelly',
#  'Then, Alexander and Jacob were working at the store. Jacob decided to give a drink to Alexander',
#  'When Cody and Michael got a ring at the garden, Michael decided to give it to Cody',
#  'After Danielle and Lindsay went to the store, Danielle gave a kiss to Lindsay',
#  'Then, Ashley and Timothy were working at the restaurant. Ashley decided to give a bone to Timothy',
#  'Then, Benjamin and Jeffrey had a lot of fun at the station. Benjamin gave a drink to Jeffrey',
#  'After James and Jesse went to the restaurant, James gave a necklace to Jesse',
#  'After Sara and Stephanie went to the restaurant, Stephanie gave a basketball to Sara',
#  'Then, Allison and Michael were thinking about going to the hospital. Michael wanted to give a snack to Allison',
#  'Then, Courtney and Dustin had a long argument, and afterwards Courtney said to Dustin',
#  'When Rebecca and Danielle got a basketball at the hospital, Rebecca decided to give it to Danielle',
#  'Then, Bradley and Andrew went to the house. Bradley gave a ring to Andrew',
#  'When Anthony and Daniel got a snack at the store, Anthony decided to give it to Daniel',
#  'Then, Alexander and Shannon were thinking about going to the school. Alexander wanted to give a ring to Shannon',
#  'After Aaron and Elizabeth went to the school, Aaron gave a ring to Elizabeth',
#  'Then, Christina and Jamie went to the office. Jamie gave a necklace to Christina',
#  'When Kyle and Justin got a drink at the school, Kyle decided to give it to Justin',
#  'When Amanda and Thomas got a drink at the restaurant, Thomas decided to give it to Amanda',
#  'Then, Joshua and Erin were working at the house. Erin decided to give a necklace to Joshua',
#  'Then, Benjamin and Jeremy went to the hospital. Benjamin gave a drink to Jeremy',
#  'Then, Sara and Allison went to the school. Allison gave a basketball to Sara',
#  'When Justin and Shannon got a drink at the store, Shannon decided to give it to Justin',
#  'After Angela and Nathan went to the house, Angela gave a basketball to Nathan',
#  'When Amber and Anthony got a snack at the garden, Anthony decided to give it to Amber',
#  'Then, Robert and Jeffrey were thinking about going to the school. Jeffrey wanted to give a ring to Robert',
#  'When Alexander and Amy got a kiss at the store, Amy decided to give it to Alexander',
#  'When Bradley and Andrea got a snack at the school, Bradley decided to give it to Andrea',
#  'When Amber and Kyle got a basketball at the school, Amber decided to give it to Kyle',
#  'Then, Ryan and Cody went to the station. Ryan gave a basketball to Cody',
#  'Then, Erica and Shannon went to the house. Erica gave a basketball to Shannon',
#  'Then, Timothy and Lauren were working at the station. Lauren decided to give a necklace to Timothy',
#  'When Kimberly and Kevin got a snack at the station, Kevin decided to give it to Kimberly',
#  'After Stephen and Courtney went to the office, Courtney gave a basketball to Stephen',
#  'Then, Jeremy and Laura had a long argument, and afterwards Laura said to Jeremy',
#  'Then, Paul and Kevin had a lot of fun at the house. Kevin gave a computer to Paul',
#  'Then, Amber and Nicholas went to the house. Nicholas gave a basketball to Amber',
#  'Then, Paul and Lindsey were working at the office. Paul decided to give a computer to Lindsey',
#  'Then, Sean and Courtney had a lot of fun at the station. Sean gave a snack to Courtney',
#  'Then, Richard and Christine went to the restaurant. Christine gave a snack to Richard',
#  'Then, Bryan and Dustin went to the store. Dustin gave a kiss to Bryan',
#  'Then, Joshua and Jose were thinking about going to the store. Jose wanted to give a drink to Joshua',
#  'Then, Elizabeth and Lisa went to the restaurant. Lisa gave a ring to Elizabeth',
#  'When Jamie and Rebecca got a snack at the store, Jamie decided to give it to Rebecca',
#  'Then, Sean and Jessica had a long argument, and afterwards Sean said to Jessica',
#  'Then, Courtney and Nathan had a lot of fun at the hospital. Nathan gave a ring to Courtney',
#  'Then, Alexander and Lindsay were working at the restaurant. Lindsay decided to give a kiss to Alexander',
#  'After Sarah and Nathan went to the school, Nathan gave a computer to Sarah',
#  'Then, Steven and Richard were thinking about going to the garden. Richard wanted to give a necklace to Steven',
#  'After Rebecca and Tyler went to the school, Rebecca gave a computer to Tyler',
#  'Then, Bradley and Ashley had a long argument, and afterwards Bradley said to Ashley',
#  'After Paul and Stephen went to the store, Paul gave a bone to Stephen',
#  'After Emily and Erin went to the office, Erin gave a kiss to Emily',
#  'Then, Elizabeth and Jennifer were working at the station. Jennifer decided to give a computer to Elizabeth',
#  'Then, Jesse and David had a lot of fun at the store. David gave a bone to Jesse',
#  'Then, Jessica and Laura were thinking about going to the restaurant. Laura wanted to give a drink to Jessica',
#  'After William and Kyle went to the school, Kyle gave a drink to William',
#  'Then, Dustin and Amber had a long argument, and afterwards Dustin said to Amber',
#  'Then, Danielle and Cody were working at the garden. Cody decided to give a drink to Danielle',
#  'When David and Brittany got a necklace at the house, David decided to give it to Brittany',
#  'Then, Steven and Kenneth had a lot of fun at the station. Kenneth gave a basketball to Steven',
#  'Then, Amy and Paul had a long argument, and afterwards Paul said to Amy',
#  'After Travis and Samuel went to the school, Samuel gave a kiss to Travis',
#  'After Sarah and Steven went to the restaurant, Steven gave a drink to Sarah',
#  'Then, Joseph and Kimberly had a long argument, and afterwards Kimberly said to Joseph',
#  'Then, Kimberly and Bradley were working at the garden. Kimberly decided to give a bone to Bradley',
#  'After Emily and Brian went to the house, Brian gave a kiss to Emily',
#  'Then, Richard and Robert had a lot of fun at the garden. Robert gave a necklace to Richard',
#  'Then, Christopher and Crystal were thinking about going to the house. Crystal wanted to give a drink to Christopher',
#  'Then, James and Courtney had a lot of fun at the school. James gave a bone to Courtney',
#  'Then, Amy and Jonathan had a long argument, and afterwards Amy said to Jonathan',
#  'When Justin and Erin got a drink at the restaurant, Erin decided to give it to Justin',
#  'When Kyle and Benjamin got a necklace at the garden, Benjamin decided to give it to Kyle',
#  'When Courtney and Megan got a basketball at the station, Megan decided to give it to Courtney',
#  'Then, Joseph and Jason were working at the store. Joseph decided to give a drink to Jason',
#  'Then, Amy and Travis had a long argument, and afterwards Travis said to Amy',
#  'After Lindsey and Gregory went to the hospital, Lindsey gave a necklace to Gregory',
#  'Then, Katie and Nicholas were thinking about going to the office. Katie wanted to give a bone to Nicholas',
#  'After Laura and Christina went to the station, Laura gave a basketball to Christina',
#  'Then, Thomas and Amy had a long argument, and afterwards Amy said to Thomas',
#  'Then, Nicholas and Andrea were thinking about going to the restaurant. Nicholas wanted to give a ring to Andrea',
#  'Then, Jacob and Shannon went to the station. Jacob gave a computer to Shannon',
#  'Then, Daniel and Katie were thinking about going to the station. Katie wanted to give a bone to Daniel',
#  'Then, Kyle and Adam had a long argument, and afterwards Kyle said to Adam',
#  'Then, Amy and David had a lot of fun at the station. Amy gave a drink to David',
#  'Then, Katie and Jamie were working at the store. Jamie decided to give a necklace to Katie',
#  'Then, Sara and Gregory went to the garden. Sara gave a kiss to Gregory',
#  'Then, Megan and Kristen had a lot of fun at the office. Megan gave a bone to Kristen',
#  'Then, Mary and Jennifer had a long argument, and afterwards Mary said to Jennifer',
#  'Then, Emily and Joseph had a lot of fun at the garden. Emily gave a computer to Joseph',
#  'When Kelly and Cody got a snack at the school, Kelly decided to give it to Cody',
#  'Then, Jacob and Michelle had a long argument, and afterwards Michelle said to Jacob',
#  'Then, Joseph and Patrick had a lot of fun at the house. Patrick gave a kiss to Joseph',
#  'After Justin and Christine went to the hospital, Christine gave a necklace to Justin',
#  'Then, Anthony and Samantha were working at the office. Anthony decided to give a snack to Samantha',
#  'After Courtney and Aaron went to the station, Aaron gave a necklace to Courtney',
#  'After Jennifer and Kyle went to the garden, Kyle gave a ring to Jennifer',
#  'Then, Bryan and Brittany were thinking about going to the restaurant. Brittany wanted to give a basketball to Bryan',
#  'Then, Paul and Stephanie were working at the office. Stephanie decided to give a drink to Paul',
#  'Then, Elizabeth and Tiffany were working at the restaurant. Elizabeth decided to give a bone to Tiffany',
#  'Then, Kristen and Emily had a long argument, and afterwards Kristen said to Emily',
#  'Then, Andrea and Mark were working at the store. Andrea decided to give a basketball to Mark',
#  'When Thomas and Allison got a kiss at the garden, Thomas decided to give it to Allison',
#  'Then, Sara and Brian had a lot of fun at the office. Sara gave a basketball to Brian',
#  'Then, Andrew and Kevin were working at the station. Andrew decided to give a necklace to Kevin',
# ...
#  'After Bryan and Kelly went to the restaurant, Bryan gave a bone to Kelly',
#  'When Mary and Melissa got a bone at the garden, Mary decided to give it to Melissa',
#  'Then, Tyler and Joshua had a long argument, and afterwards Tyler said to Joshua',
#  'When Daniel and Jose got a basketball at the garden, Jose decided to give it to Daniel',
#  'Then, Katherine and Sean went to the office. Katherine gave a bone to Sean',
#  'Then, Lindsey and Adam had a long argument, and afterwards Lindsey said to Adam',
#  'When Laura and Sean got a computer at the office, Laura decided to give it to Sean',
#  'Then, Katherine and Sarah went to the office. Katherine gave a necklace to Sarah',
#  'After Jonathan and Michael went to the school, Jonathan gave a basketball to Michael',
#  'Then, Alicia and Bryan went to the hospital. Alicia gave a necklace to Bryan',
#  'Then, Christine and Alexander went to the station. Alexander gave a snack to Christine',
#  'Then, Richard and Rachel were working at the garden. Richard decided to give a bone to Rachel',
#  'Then, Erica and James had a long argument, and afterwards Erica said to James',
#  'When Lisa and Christine got a ring at the garden, Christine decided to give it to Lisa',
#  'Then, Lisa and Jamie were thinking about going to the house. Jamie wanted to give a basketball to Lisa',
#  'Then, Kevin and Paul had a lot of fun at the station. Paul gave a bone to Kevin',
#  'Then, Eric and Michelle had a long argument, and afterwards Michelle said to Eric',
#  'Then, Jamie and Kelly were working at the house. Jamie decided to give a necklace to Kelly',
#  'Then, Kristen and Christopher were working at the restaurant. Christopher decided to give a bone to Kristen',
#  'Then, William and Stephanie were working at the restaurant. William decided to give a snack to Stephanie',
#  'Then, Eric and Jennifer had a long argument, and afterwards Jennifer said to Eric',
#  'After Jeffrey and Kevin went to the store, Kevin gave a basketball to Jeffrey',
#  'Then, Crystal and Kimberly were working at the station. Kimberly decided to give a ring to Crystal',
#  'Then, Lauren and Lindsey had a lot of fun at the hospital. Lindsey gave a computer to Lauren',
#  'Then, Dustin and Tyler were thinking about going to the house. Dustin wanted to give a drink to Tyler',
#  'Then, Lindsey and Andrea had a long argument, and afterwards Andrea said to Lindsey',
#  'When Samantha and Tiffany got a snack at the office, Samantha decided to give it to Tiffany',
#  'Then, Patrick and Erica had a lot of fun at the restaurant. Patrick gave a snack to Erica',
#  'Then, David and Elizabeth went to the hospital. Elizabeth gave a basketball to David',
#  'Then, William and Brian went to the garden. Brian gave a basketball to William',
#  'After Amber and Courtney went to the station, Amber gave a snack to Courtney',
#  'Then, Anthony and Andrea were working at the house. Anthony decided to give a ring to Andrea',
#  'When Jennifer and Brandon got a bone at the restaurant, Jennifer decided to give it to Brandon',
#  'Then, Kelly and Jennifer had a long argument, and afterwards Kelly said to Jennifer',
#  'Then, Brian and Kevin went to the house. Kevin gave a ring to Brian',
#  'Then, Christine and Kristen went to the garden. Christine gave a basketball to Kristen',
#  'Then, Erica and Stephen were working at the restaurant. Erica decided to give a basketball to Stephen',
#  'Then, Gregory and Jeremy were thinking about going to the restaurant. Jeremy wanted to give a computer to Gregory',
#  'Then, Jesse and Courtney went to the station. Courtney gave a kiss to Jesse',
#  'When Amy and Crystal got a ring at the garden, Amy decided to give it to Crystal',
#  'When Samantha and Jamie got a bone at the house, Samantha decided to give it to Jamie',
#  'Then, John and Stephanie were thinking about going to the store. John wanted to give a kiss to Stephanie',
#  'After Kristen and Patrick went to the store, Patrick gave a drink to Kristen',
#  'Then, Jeffrey and Benjamin were working at the house. Benjamin decided to give a basketball to Jeffrey',
#  'Then, Patrick and Samuel had a lot of fun at the office. Patrick gave a kiss to Samuel',
#  'After Jason and Melissa went to the school, Jason gave a kiss to Melissa',
#  'When Dustin and Gregory got a basketball at the hospital, Gregory decided to give it to Dustin',
#  'Then, Cody and Shannon had a lot of fun at the garden. Shannon gave a ring to Cody',
#  'After Lindsey and Anthony went to the office, Lindsey gave a drink to Anthony',
#  'Then, Sarah and Joseph had a long argument, and afterwards Joseph said to Sarah',
#  'Then, Mark and Sara were thinking about going to the office. Sara wanted to give a computer to Mark',
#  'Then, Michelle and Allison had a long argument, and afterwards Michelle said to Allison',
#  'Then, Melissa and Patrick went to the office. Patrick gave a drink to Melissa',
#  'Then, Jason and Kristen went to the school. Jason gave a snack to Kristen',
#  'Then, Lindsay and William had a lot of fun at the school. Lindsay gave a drink to William',
#  'Then, Brittany and Paul had a lot of fun at the store. Brittany gave a bone to Paul',
#  'After Kenneth and Michael went to the restaurant, Kenneth gave a snack to Michael',
#  'Then, Emily and Robert were thinking about going to the hospital. Emily wanted to give a basketball to Robert',
#  'Then, Erica and James had a long argument, and afterwards James said to Erica',
#  'Then, Lindsey and Samantha were thinking about going to the store. Lindsey wanted to give a bone to Samantha',
#  'Then, Erin and Aaron had a long argument, and afterwards Erin said to Aaron',
#  'When Ashley and Gregory got a bone at the school, Ashley decided to give it to Gregory',
#  'Then, Ashley and Kimberly had a long argument, and afterwards Ashley said to Kimberly',
#  'After Tiffany and Thomas went to the house, Thomas gave a drink to Tiffany',
#  'Then, Nicholas and Samantha were thinking about going to the garden. Nicholas wanted to give a kiss to Samantha',
#  'Then, Courtney and Timothy were working at the office. Timothy decided to give a necklace to Courtney',
#  'Then, Eric and Thomas were thinking about going to the school. Thomas wanted to give a snack to Eric',
#  'After Scott and Michael went to the restaurant, Scott gave a drink to Michael',
#  'Then, Angela and Joseph were working at the hospital. Joseph decided to give a necklace to Angela',
#  'After Melissa and Kelly went to the hospital, Kelly gave a snack to Melissa',
#  'After Tyler and Patrick went to the school, Tyler gave a necklace to Patrick',
#  'Then, Andrea and Matthew had a lot of fun at the garden. Andrea gave a computer to Matthew',
#  'After Kenneth and Amy went to the school, Amy gave a necklace to Kenneth',
#  'After Richard and Samantha went to the store, Richard gave a computer to Samantha',
#  'When Timothy and Robert got a kiss at the office, Timothy decided to give it to Robert',
#  'Then, Stephen and Stephanie were working at the office. Stephanie decided to give a basketball to Stephen',
#  'Then, Steven and Brian were thinking about going to the school. Steven wanted to give a snack to Brian',
#  'Then, Nicholas and Adam went to the school. Nicholas gave a computer to Adam',
#  'When Elizabeth and Nicholas got a bone at the office, Elizabeth decided to give it to Nicholas',
#  'Then, Joseph and Ryan had a lot of fun at the station. Joseph gave a ring to Ryan',
#  'Then, Dustin and Jennifer had a lot of fun at the office. Dustin gave a necklace to Jennifer',
#  'Then, Scott and Thomas were working at the restaurant. Scott decided to give a computer to Thomas',
#  'After Eric and Allison went to the restaurant, Eric gave a ring to Allison',
#  'Then, Patrick and Mark were working at the store. Mark decided to give a necklace to Patrick',
#  'After Jesse and Stephanie went to the garden, Jesse gave a snack to Stephanie',
#  'Then, Anthony and Alexander had a long argument, and afterwards Alexander said to Anthony',
#  'Then, Kevin and Mary had a long argument, and afterwards Mary said to Kevin',
#  'When Mary and Stephen got a bone at the office, Stephen decided to give it to Mary',
#  'Then, Mark and Anthony were working at the office. Mark decided to give a necklace to Anthony',
#  'Then, Thomas and Tiffany were thinking about going to the restaurant. Tiffany wanted to give a bone to Thomas',
#  'Then, Jesse and Elizabeth were thinking about going to the hospital. Jesse wanted to give a basketball to Elizabeth',
#  'Then, Amy and Emily were working at the restaurant. Emily decided to give a bone to Amy',
#  'Then, Christopher and Stephanie were working at the station. Christopher decided to give a bone to Stephanie',
#  'Then, Samantha and Lisa were thinking about going to the office. Lisa wanted to give a snack to Samantha',
#  'When Angela and Melissa got a drink at the store, Melissa decided to give it to Angela',
#  'After William and Katie went to the school, Katie gave a computer to William',
#  'Then, Lisa and John were working at the office. Lisa decided to give a computer to John',
#  'Then, Danielle and Melissa had a long argument, and afterwards Melissa said to Danielle',
#  'Then, Erica and Alexander had a long argument, and afterwards Alexander said to Erica',
#  'Then, Alexander and Lauren had a long argument, and afterwards Lauren said to Alexander',
#  'After Mary and Amy went to the station, Amy gave a bone to Mary',
#  'Then, Kenneth and Jonathan were thinking about going to the house. Jonathan wanted to give a drink to Kenneth',
#  'Then, James and David were thinking about going to the office. David wanted to give a basketball to James',
#  'Then, Lindsey and Laura had a long argument, and afterwards Laura said to Lindsey',
#  'When Kimberly and Aaron got a drink at the station, Aaron decided to give it to Kimberly',
#  'Then, Jessica and Brian went to the school. Brian gave a computer to Jessica',
#  'Then, Lindsay and Cody went to the school. Lindsay gave a bone to Cody',
#  'After Joseph and John went to the station, Joseph gave a ring to John',
#  'Then, Michelle and Samuel had a lot of fun at the garden. Samuel gave a kiss to Michelle',
#  'When Sarah and Travis got a computer at the house, Travis decided to give it to Sarah',
#  'When Megan and Alicia got a bone at the station, Megan decided to give it to Alicia',
#  'Then, Jonathan and Nathan went to the store. Nathan gave a necklace to Jonathan',
#  'Then, Stephen and Lauren were thinking about going to the hospital. Lauren wanted to give a snack to Stephen',
#  'Then, Dustin and Lindsay went to the station. Lindsay gave a drink to Dustin',
#  'Then, Danielle and Rachel were working at the school. Rachel decided to give a kiss to Danielle',
#  'Then, Rachel and Kimberly were working at the hospital. Rachel decided to give a bone to Kimberly',
#  'When Michael and Christopher got a necklace at the restaurant, Christopher decided to give it to Michael',
#  'When Sara and Stephen got a snack at the station, Stephen decided to give it to Sara',
#  'When Samuel and Christopher got a basketball at the hospital, Christopher decided to give it to Samuel',
#  'Then, Michael and Paul had a lot of fun at the school. Michael gave a drink to Paul',
#  'Then, Michelle and Emily were working at the restaurant. Emily decided to give a drink to Michelle',
#  'Then, Eric and Amy were thinking about going to the garden. Amy wanted to give a drink to Eric',
#  'Then, Adam and Samantha had a long argument, and afterwards Adam said to Samantha',
#  'Then, Cody and Sara had a long argument, and afterwards Cody said to Sara',
#  'Then, Brian and Daniel were thinking about going to the hospital. Daniel wanted to give a kiss to Brian',
#  'Then, Rebecca and Travis had a long argument, and afterwards Rebecca said to Travis',
#  'When Lauren and Jessica got a ring at the store, Lauren decided to give it to Jessica',
#  'Then, Timothy and Joseph went to the restaurant. Joseph gave a snack to Timothy',
#  'Then, Christopher and Elizabeth went to the restaurant. Christopher gave a ring to Elizabeth',
#  'Then, Heather and Brittany were working at the hospital. Heather decided to give a snack to Brittany',
#  'Then, Lindsay and Jacob had a long argument, and afterwards Jacob said to Lindsay',
#  'Then, Justin and Allison were thinking about going to the hospital. Allison wanted to give a drink to Justin',
#  'After Stephen and Dustin went to the school, Dustin gave a computer to Stephen',
#  'Then, Christopher and Amy were thinking about going to the school. Amy wanted to give a drink to Christopher',
#  'Then, Aaron and Megan had a lot of fun at the store. Aaron gave a basketball to Megan',
#  'Then, Alicia and Samuel were working at the school. Alicia decided to give a snack to Samuel',
#  'After Jesse and Rachel went to the restaurant, Jesse gave a ring to Rachel',
#  'Then, Paul and Samantha went to the hospital. Paul gave a snack to Samantha',
#  'Then, Kyle and Nicholas had a long argument, and afterwards Kyle said to Nicholas',
#  'After Kenneth and Adam went to the office, Adam gave a ring to Kenneth',
#  'Then, Katherine and Thomas went to the house. Thomas gave a basketball to Katherine',
#  'Then, Katherine and Jennifer had a lot of fun at the station. Jennifer gave a bone to Katherine',
#  'Then, Robert and Samuel had a long argument, and afterwards Samuel said to Robert',
#  'After Travis and Jesse went to the store, Jesse gave a ring to Travis',
#  'Then, Sarah and Bryan had a long argument, and afterwards Bryan said to Sarah',
#  'Then, Elizabeth and Laura were working at the office. Elizabeth decided to give a snack to Laura',
#  'Then, Nicole and Jessica went to the house. Nicole gave a necklace to Jessica',
#  'Then, Jason and Melissa went to the station. Jason gave a snack to Melissa',
#  'Then, Dustin and Christina were working at the station. Christina decided to give a basketball to Dustin',
#  'Then, Brian and Dustin were thinking about going to the office. Brian wanted to give a snack to Dustin',
#  'When Paul and Gregory got a bone at the garden, Gregory decided to give it to Paul',
#  'Then, Christina and Kevin were working at the office. Christina decided to give a snack to Kevin',
#  'Then, Jamie and Kenneth had a lot of fun at the restaurant. Kenneth gave a ring to Jamie',
#  'Then, Kimberly and Travis were thinking about going to the office. Kimberly wanted to give a kiss to Travis',
#  'Then, Sara and Crystal had a long argument, and afterwards Sara said to Crystal',
#  'Then, Timothy and Lauren were thinking about going to the office. Timothy wanted to give a kiss to Lauren',
#  'After Kristen and Samantha went to the store, Samantha gave a bone to Kristen',
#  'Then, Nicholas and Ashley went to the station. Ashley gave a basketball to Nicholas',
#  'After Scott and Ashley went to the house, Ashley gave a snack to Scott',
#  'Then, Lindsay and Travis were working at the hospital. Travis decided to give a ring to Lindsay',
#  'Then, Erica and Eric had a long argument, and afterwards Eric said to Erica',
#  'When Lindsey and Sean got a ring at the station, Lindsey decided to give it to Sean',
#  'Then, Cody and Angela had a long argument, and afterwards Angela said to Cody',
#  'Then, Steven and Mary were thinking about going to the store. Mary wanted to give a kiss to Steven',
#  'Then, David and Kyle were thinking about going to the garden. Kyle wanted to give a kiss to David',
#  'Then, Elizabeth and Sara went to the school. Elizabeth gave a basketball to Sara',
#  'Then, Megan and Kristen were working at the restaurant. Kristen decided to give a drink to Megan',
#  'Then, Joseph and Samuel went to the office. Joseph gave a snack to Samuel',
#  'Then, Jose and Mark went to the restaurant. Jose gave a bone to Mark',
#  'Then, Jamie and Tiffany were working at the restaurant. Tiffany decided to give a snack to Jamie',
#  'Then, Paul and Laura had a long argument, and afterwards Laura said to Paul',
#  'Then, Kenneth and Emily had a lot of fun at the office. Kenneth gave a basketball to Emily',
#  'Then, Dustin and Heather were thinking about going to the hospital. Dustin wanted to give a necklace to Heather',
#  ...]
